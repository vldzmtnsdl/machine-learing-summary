# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %%
apple=pd.read_csv("appl_1980_2014.csv")
apple.head(5)
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8465 non-null   object
#  1   Open       8465 non-null   float64
#  2   High       8465 non-null   float64
#  3   Low        8465 non-null   float64
#  4   Close      8465 non-null   float64
#  5   Volume     8465 non-null   int64
#  6   Adj Close  8465 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 463.1+ KB

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
apple['Date']=pd.to_datetime(apple['Date'])

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple.index=apple['Date']
apple
# Out:
#                  Date   Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...               ...    ...    ...    ...    ...        ...        ...
# 1980-12-18 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
apple['Date'].value_counts()[apple['Date'].value_counts()!=1]
# Out:
# Series([], Name: Date, dtype: int64)

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
apple.sort_index(ascending=True)
# Out:
#                  Date   Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...               ...    ...    ...    ...    ...        ...        ...
# 2014-07-01 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
apple['yearmonth']=apple['Date'].dt.strftime('%y-%m')
for i in apple['yearmonth'].values:
    x=apple[apple['yearmonth']==i]
    print(x['Date'].min())
# Out:
# 2014-07-01 00:00:00
# 2014-07-01 00:00:00
# 2014-07-01 00:00:00
# 2014-07-01 00:00:00
# 2014-07-01 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-06-02 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# 2014-05-01 00:00:00
# ...

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
apple['Date'].max()-apple['Date'].min()
# Out:
# Timedelta('12261 days 00:00:00')

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
apple['month']=apple['Date'].dt.month
apple['month'].value_counts()
# Out:
# 3     744
# 8     730
# 10    728
# 6     727
# 5     718
# 12    711
# 1     705
# 7     703
# 4     703
# 11    675
# 9     669
# 2     652
# Name: month, dtype: int64

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
ax=plt.figure(figsize=(13.5,9))
ax=plt.plot('Adj Close',data=apple)

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# ## 거래량과 주가의 관계: 거래량이 많으면 주가 변동이 클까?

# %%
apple.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close', 'month'], dtype='object')

# %%
apple['change']=apple['High']-apple['Low']

# %%
fig2=plt.figure(figsize=(13.5,9))
ax2=sns.regplot('Volume','change',data=apple,fit_reg=True)
